# %%
import pandas as pd
from pandas import *
import os

# %% [markdown]
# ## step 1 - copy calendar to excel and save as csv

# %%
os.chdir('/home/jp/DATA/Dropbox/school/cloud/owlsbrew/Demo Calendars')

# %%
files = ['January','February','March','April','May','June','July','August','September']

# %%
i = 5
df = read_csv('demo csv/' + files[i] + '.csv')

# %%
df
# Out:
#     Monday               Tuesday                     Wednesday  \
# 0      NaN                   NaN                           NaN
# 1      NaN                   NaN                           NaN
# 2        2                     3                             4
# 3      NaN   WFM Tribeca 4pm-7pm                           NaN
# 4        9                    10                            11
# 5      NaN                   NaN                           NaN
# 6       16                    17                            18
# 7      NaN                   NaN  Union Market Houston 4pm-7pm
# 8       23                    24                            25
# 9      NaN  WFM Chelsea 4pm-7pm                            NaN
# 10      30                   NaN                           NaN
#
#                                              Thursday  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   5
# 3                                                 NaN
# 4                                                  12
# 5                   West Elm Broadway, 4pm-7pm (NINA)
# 6                                                  19
# 7                                 WFM Tribeca 4pm-7pm
# 8                                                  26
# 9   Union Market Houston 4pm-7pm / Di Bruno Bros. ...
# 10                                                NaN
#
#                             Friday  \
# 0                              NaN
# 1                              NaN
# 2                                6
# 3                              NaN
# 4                               13
# 5                              NaN
# 6                               20
# 7   WFM University Heights 3pm-6pm
# 8                               27
# 9   Williams-Sonoma Boston 3pm-6pm
# 10                             NaN
#
#                                              Saturday  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                   7
# 3   Southern Seasons Chapel Hill event w sampling ...
# 4                                                  14
# 5                                                 NaN
# 6                                                  21
# 7               Brooklyn Victory Garden 1:30pm-3:30pm
# 8                                                  28
# 9                        DiBrunos Rittenhouse 2pm-5pm
# 10                                                NaN
#
#                                                Sunday
# 0                                                   1
# 1                                                 NaN
# 2                                                   8
# 3                                                 NaN
# 4                                                  15
# 5                            Olives & Grace 12pm-3pm
# 6                                                  22
# 7   TFM (30 demos w Interactions) 12pm-4pm / Forag...
# 8                                                  29
# 9                          Williams-Sonoma DC 3pm-6pm
# 10                                                NaN
#
# [11 rows x 7 columns]

# %%
calendar = {}
for col in df.columns:
    first = True
    for row in df.index:
        if first == True:
            date = df.loc[row,col]
            day = [files[i],col,date] # month, day, date
            first = False
        else:
            if (type(date) == float or type(date) == numpy.float64) and np.isnan(date):
                pass
                first = True            
            else:
                date = int(date)
                day.append(df.loc[row,col])
                first = True
                calendar[date] = day
    if (type(date) == float or type(date) == numpy.float64) and np.isnan(date) or len(df) % 2 != 1:
        pass
    else:
        day.append(float(nan))
        calendar[date] = day
# Out:
# ['June', 'Monday', nan]
# ['June', 'Monday', 2.0]
# 2.0
# ['June', 'Monday', 9.0]
# 9.0
# ['June', 'Monday', 16.0]
# 16.0
# ['June', 'Monday', 23.0]
# 23.0
# ['June', 'Monday', 30.0]
# ['June', 'Tuesday', nan]
# ['June', 'Tuesday', '3']
# 3
# ['June', 'Tuesday', '10']
# 10
# ['June', 'Tuesday', '17']
# 17
# ['June', 'Tuesday', '24']
# 24
# ['June', 'Tuesday', nan]
# ['June', 'Wednesday', nan]
# ['June', 'Wednesday', '4']
# 4
# ['June', 'Wednesday', '11']
# 11
# ['June', 'Wednesday', '18']
# 18
# ['June', 'Wednesday', '25']
# 25
# ['June', 'Wednesday', nan]
# ['June', 'Thursday', nan]
# ['June', 'Thursday', '5']
# 5
# ['June', 'Thursday', '12']
# 12
# ['June', 'Thursday', '19']
# 19
# ['June', 'Thursday', '26']
# 26
# ['June', 'Thursday', nan]
# ['June', 'Friday', nan]
# ['June', 'Friday', '6']
# 6
# ['June', 'Friday', '13']
# 13
# ['June', 'Friday', '20']
# 20
# ['June', 'Friday', '27']
# 27
# ['June', 'Friday', nan]
# ['June', 'Saturday', nan]
# ['June', 'Saturday', '7']
# 7
# ['June', 'Saturday', '14']
# 14
# ['June', 'Saturday', '21']
# 21
# ['June', 'Saturday', '28']
# 28
# ['June', 'Saturday', nan]
# ['June', 'Sunday', '1']
# 1
# ['June', 'Sunday', '8']
# 8
# ['June', 'Sunday', '15']
# 15
# ['June', 'Sunday', '22']
# 22
# ['June', 'Sunday', '29']
# 29
# ['June', 'Sunday', nan]

# %%
month = DataFrame.from_dict(calendar, orient = 'index')
month.columns = 'Month','Day','Date','Info'

month.loc[:,'Info'] = month.loc[:,'Info'].apply(lambda x: 
        x if type(x) == float 
        or type(x) == numpy.float64 
        else x.decode('ascii', 'ignore'))

# %%
# month.to_csv('apr.csv')
month
# Out:
#    Month        Day Date                                               Info
# 1   June     Sunday    1                                                NaN
# 2   June     Monday    2                                                NaN
# 3   June    Tuesday    3                                WFM Tribeca 4pm-7pm
# 4   June  Wednesday    4                                                NaN
# 5   June   Thursday    5                                                NaN
# 6   June     Friday    6                                                NaN
# 7   June   Saturday    7  Southern Seasons Chapel Hill event w sampling ...
# 8   June     Sunday    8                                                NaN
# 9   June     Monday    9                                                NaN
# 10  June    Tuesday   10                                                NaN
# 11  June  Wednesday   11                                                NaN
# 12  June   Thursday   12                  West Elm Broadway, 4pm-7pm (NINA)
# 13  June     Friday   13                                                NaN
# 14  June   Saturday   14                                                NaN
# 15  June     Sunday   15                           Olives & Grace 12pm-3pm
# 16  June     Monday   16                                                NaN
# 17  June    Tuesday   17                                                NaN
# 18  June  Wednesday   18                       Union Market Houston 4pm-7pm
# 19  June   Thursday   19                                WFM Tribeca 4pm-7pm
# 20  June     Friday   20                     WFM University Heights 3pm-6pm
# 21  June   Saturday   21              Brooklyn Victory Garden 1:30pm-3:30pm
# 22  June     Sunday   22  TFM (30 demos w Interactions) 12pm-4pm / Forag...
# 23  June     Monday   23                                                NaN
# 24  June    Tuesday   24                               WFM Chelsea 4pm-7pm
# 25  June  Wednesday   25                                                NaN
# 26  June   Thursday   26  Union Market Houston 4pm-7pm / Di Bruno Bros. ...
# 27  June     Friday   27                     Williams-Sonoma Boston 3pm-6pm
# 28  June   Saturday   28                       DiBrunos Rittenhouse 2pm-5pm
# 29  June     Sunday   29                         Williams-Sonoma DC 3pm-6pm
# 30  June     Monday   30                                                NaN
#
# [30 rows x 4 columns]
